# %% [markdown]
# # 1. Download data

# %%
# !pip install pycountry

# %%
import pycountry
import plotly.express as px
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

URL_DATASET = r'https://raw.githubusercontent.com/datasets/covid-19/master/data/countries-aggregated.csv'
df1 = pd.read_csv(URL_DATASET)
print(df1.head(3))  # Get first 3 entries in the dataframe
print(df1.tail(3))  # Get last 3 entries in the dataframe
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-23  Afghanistan          0          0       0
# 2  2020-01-24  Afghanistan          0          0       0
#              Date   Country  Confirmed  Recovered  Deaths
# 73341  2021-02-04  Zimbabwe      34171      27759    1288
# 73342  2021-02-05  Zimbabwe      34331      28145    1303
# 73343  2021-02-06  Zimbabwe      34487      28383    1316

# %% [markdown]
# # 2. Select data for Country

# %%
df_Russia = df1[df1['Country'] == 'Russia']
print(df_Russia.tail(3))
# Out:
#              Date Country  Confirmed  Recovered  Deaths
# 54623  2021-02-04  Russia    3874830    3352720   74005
# 54624  2021-02-05  Russia    3891274    3375999   74520
# 54625  2021-02-06  Russia    3907653    3398545   75010

# %% [markdown]
# # 3. Plot data

# %%
# Increase size of plot
plt.rcParams["figure.figsize"]=20,20  # Remove if not on Jupyter
# Plot column 'Confirmed'
df_Russia.plot(kind = 'bar', x = 'Date', y = 'Confirmed', color = 'blue')

ax1 = plt.gca()
df_Russia.plot(kind = 'bar', x = 'Date', y = 'Deaths', color = 'red', ax = ax1)
plt.show()

# %% [markdown]
# # Task 1: Formalisation of Consumer Shopping Behaviour
# A consumer `i` shops in week `t` at a retailer `r`.
# In each category `c`, the retailer offers multiple products `j`.
#
# 1) Which probability distributions would you use to model each of the three components:
#
#
# - probability of category purchase $$ P (I_{ict} = 1) $$ - равномерное дискретное распределение с вероятностью `p = 1/N`, где `N` - количество категорий
#
#
# - the probability of product choice within a category  $$ P ( C_{it}=j |  I_{ict} = 1)$$ - равномерное дискретное распределение с вероятностью `p = 1/Nc`, где `Nc` - количество наименований товаров в категории `c`
#
# - and the probability for the purchased amount $$ P ( Q_{ijt}|I_{ict}=1 ^ C_{it}=j)$$
