# %% [markdown]
# # Covid-19 graphs and Peak Tracking
# (New Cases) vs (New Daily Recovered) graph added

# %%
from utils import *

# %% [markdown]
# # Общая статистика заражения
# В расчётах принято что пик заражения пройден, если за день выздоровело больше, чем заболело

# %%
world_peak_detection, df_cpd = detect_peak(df)
# Out:
# 1. Глобальный пик заражения COVID-19 еще НЕ ПРОЙДЕН
#
# 2. Пик заражения пройден в 46/173=26.6% стран.
#
# 3. Список стран c "Total Cases">1000, где пик заражения пройден:
#
# Afghanistan|Albania|Belarus|Belize|Bolivia|Botswana|Central African Republic|Chad|China|Comoros|Congo (Kinshasa)|Cuba|Equatorial Guinea|Eritrea|Estonia|Eswatini|Gambia|Georgia|Haiti|Israel|Libya|Luxembourg|Malawi|Malaysia|Malta|Monaco|Montenegro|Morocco|Mozambique|Namibia|New Zealand|Niger|Nigeria|Panama|Portugal|Russia|Rwanda|Saint Lucia|Sao Tome and Principe|Senegal|Sierra Leone|Slovenia|Sri Lanka|Tunisia|United Arab Emirates|Zimbabwe

# %%
df['China'][['Active Cases', 'Daily New Cases', 'Daily New Recovered']].tail()
# Out:
#            Active Cases Daily New Cases Daily New Recovered
# 2021-03-14          505              29                  29
# 2021-03-15          523              43                  25
# 2021-03-16          518              22                  27
# 2021-03-17          499              17                  36
# 2021-03-18          490              21                  30

# %% [markdown]
# # 1. China, world

# %%
plot_locations3(df, locations = ['China', 'world'])

# %% [markdown]
# # 2. United States

# %%
plot_locations3(df, locations = ['US'])

# %% [markdown]
# # 3. Europe

# %%
plot_locations3(df, locations = ['Italy', 'Spain', 'Germany', 'France'])

# %% [markdown]
# # 4. Russia, Ukraine, Belarus

# %%
plot_locations3(df, locations = ['Russia', 'Ukraine', 'Belarus'])

# %% [markdown]
# # 5. Some other locations

# %%
locations = ['Iran', 'United Kingdom', 'Turkey', 'Switzerland','Belgium', 'Netherlands', 'Canada',
             'Austria', 'Korea, South', 'Portugal', 'Brazil', 'Israel', 'Sweden', 'Australia', 'Norway','Japan']
plot_locations3(df, locations)

# %%
print(api.show_available_countries())
