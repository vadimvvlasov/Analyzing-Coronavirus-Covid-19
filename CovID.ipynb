# %% [markdown]
# # Analyzing Coronavirus (Covid-19)
# <!-- https://towardsdatascience.com/analyzing-coronavirus-covid-19-data-using-pandas-and-plotly-2e34fe2c4edc -->
# The data is hosted by John Hopkins University and can be found in the link here.

# %%
# !pip install covid-data-api

# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import *

# %%
countries = ['China', 'US', 'Italy', 'Spain', 'Germany', 'France', 'Russia']
# for country in countries:
#     if country in api.show_available_countries():
#         print('Ok')
#     else:
#         print(f'{country} not exists')

# %%
covid_cases = {}
for country in countries:
    covid_cases[country] = get_df(country)
    covid_cases[country] = add_cases(covid_cases[country])

# %%
for loc in countries:
    plt_cases(covid_cases, loc)
